# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
data_frame = pd.read_csv("transfusion.data")
data_frame
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# ...

# %%
data_frame.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        748.000000         748.000000             748.000000
# mean           9.506684           5.514706            1378.676471
# std            8.095396           5.839307            1459.826781
# min            0.000000           1.000000             250.000000
# 25%            2.750000           2.000000             500.000000
# 50%            7.000000           4.000000            1000.000000
# 75%           14.000000           7.000000            1750.000000
# max           74.000000          50.000000           12500.000000
#
#        Time (months)  whether he/she donated blood in March 2007
# count     748.000000                                  748.000000
# mean       34.282086                                    0.237968
# std        24.376714                                    0.426124
# min         2.000000                                    0.000000
# ...

# %%
col1 = "Recency (months)"
col2 = "Frequency (times)"
col3 = "Monetary (c.c. blood)"
col4 = "Time (months)"
col5 = "whether he/she donated blood in March 2007"

# %%
fig, axs = plt.subplots(3,2,figsize=(15,15))
axs[0][0].plot(data_frame[[col1]],'.',color='r')
axs[0][0].set_title(col1)
axs[0][1].plot(data_frame[[col2]],'.')
axs[0][1].set_title(col2)
axs[1][0].plot(data_frame[[col3]],'.',color = 'y')
axs[1][0].set_title(col3)
axs[1][1].plot(data_frame[[col4]],'.',color = 'g')
axs[1][1].set_title(col4)
axs[2][0].plot(data_frame[[col5]],'.', color = 'c')
axs[2][0].set_title(col5)
fig.delaxes(axs[2][1])

# %%
data_frame.corr()
# Out:
#                                             Recency (months)  \
# Recency (months)                                    1.000000
# Frequency (times)                                  -0.182745
# Monetary (c.c. blood)                              -0.182745
# Time (months)                                       0.160618
# whether he/she donated blood in March 2007         -0.279869
#
#                                             Frequency (times)  \
# Recency (months)                                    -0.182745
# Frequency (times)                                    1.000000
# Monetary (c.c. blood)                                1.000000
# Time (months)                                        0.634940
# whether he/she donated blood in March 2007           0.218633
#
#                                             Monetary (c.c. blood)  \
# Recency (months)                                        -0.182745
# Frequency (times)                                        1.000000
# ...

# %%
data_frame = data_frame.iloc[:,[0,1,2,3]]
scatter_matrix(data_frame[data_frame.columns], figsize=(12, 12) , color = 'c' , marker='o' )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B40BC98430>,
# ...
#       dtype=object)

# %%
fig, axs = plt.subplots(2,2,figsize=(10,15))
axs[0][0].boxplot(data_frame[col1])
axs[0][0].set_title(col1)
axs[0][1].boxplot(data_frame[col2])
axs[0][1].set_title(col2)
axs[1][0].boxplot(data_frame[col3])
axs[1][0].set_title(col3)
axs[1][1].boxplot(data_frame[col4])
axs[1][1].set_title(col4)
plt.show()

# %%
col1 = "Recency (months)"
col2 = "Frequency (times)"
col3 = "Monetary (c.c. blood)"
col4 = "Time (months)"
col5 = "whether he/she donated blood in March 2007"

# %%
fig, axs = plt.subplots(2,2, figsize=(15, 10))
ax1 = sns.boxplot(col5, col1, hue=col5, data=data_frame, ax = axs[0][0])
ax2 = sns.boxplot(col5, col2, hue=col5, data=data_frame, ax = axs[0][1])
ax3 = sns.boxplot(col5, col3, hue=col5, data=data_frame, ax = axs[1][0])
ax4 = sns.boxplot(col5, col4, hue=col5, data=data_frame, ax = axs[1][1])
